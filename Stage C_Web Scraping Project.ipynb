# %%
#installing BeautifulSoup4

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing necessary libraries

# %%
from bs4 import BeautifulSoup  
import pandas as pd
from urllib.request import urlopen
import requests

# %%
# calling up the web site to be scrapped from Statista

# %%
source_url = 'https://www.statista.com/topics/1164/social-networks/#dossierContents__outerWrapper'
data = urlopen(source_url)
page_html = data.read()
data.close()

# %%
source_url = BeautifulSoup(page_html, 'html.parser')

# %%
requests.get(source_url)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 requests.get(source_url)
#
# File ~\anaconda3\envs\hamoye\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\envs\hamoye\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
# ...

# %%
soup = BeautifulSoup(source_url, 'lxml')

# %%
# installing a parser library

# %%
pip install lxml

# %%
import lxml

# %%
soup = BeautifulSoup(source_url, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 soup = BeautifulSoup(source_url, 'lxml')
#
# File ~\anaconda3\envs\hamoye\lib\site-packages\bs4\__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# ...

# %%
filename = "class, list__item padding-bottom-s-10"
filename.get(headers).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 filename = "class, list__item padding-bottom-s-10"
# ----> 2 filename.get(headers).text
#
# AttributeError: 'str' object has no attribute 'get'

# %%
print
