# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2823-EFB5
#
#  Directory of C:\quiz
#
# 07/26/2022  08:27 PM    <DIR>          .
# 07/26/2022  08:27 PM    <DIR>          ..
# 07/26/2022  09:14 AM    <DIR>          .ipynb_checkpoints
# 07/23/2022  04:11 PM         8,603,007 FoodBalanceSheets_E_Africa_NOFLAG.csv
# 07/26/2022  09:22 AM            11,854 Quiz1.ipynb
#                2 File(s)      8,614,861 bytes
#                3 Dir(s)  421,347,635,200 bytes free

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.tail(20)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60923        181  Zimbabwe       2680    Infant food          5611
# 60924        181  Zimbabwe       2680    Infant food          5072
# 60925        181  Zimbabwe       2680    Infant food          5911
# 60926        181  Zimbabwe       2680    Infant food          5301
# 60927        181  Zimbabwe       2680    Infant food          5170
# 60928        181  Zimbabwe       2680    Infant food          5142
# 60929        181  Zimbabwe       2680    Infant food           645
# 60930        181  Zimbabwe       2680    Infant food           664
# 60931        181  Zimbabwe       2680    Infant food           674
# 60932        181  Zimbabwe       2680    Infant food           684
# 60933        181  Zimbabwe       2899  Miscellaneous          5611
# 60934        181  Zimbabwe       2899  Miscellaneous          5072
# 60935        181  Zimbabwe       2899  Miscellaneous          5911
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df["Element"]
# Out:
# 0                 Total Population - Both sexes
# 1                      Domestic supply quantity
# 2                 Food supply (kcal/capita/day)
# 3        Protein supply quantity (g/capita/day)
# 4            Fat supply quantity (g/capita/day)
#                           ...
# 60938                                      Food
# 60939       Food supply quantity (kg/capita/yr)
# 60940             Food supply (kcal/capita/day)
# 60941    Protein supply quantity (g/capita/day)
# 60942        Fat supply quantity (g/capita/day)
# Name: Element, Length: 60943, dtype: object

# %%
list(df["Element"].unique())
# Out:
# ['Total Population - Both sexes',
#  'Domestic supply quantity',
#  'Food supply (kcal/capita/day)',
#  'Protein supply quantity (g/capita/day)',
#  'Fat supply quantity (g/capita/day)',
#  'Production',
#  'Import Quantity',
#  'Stock Variation',
#  'Export Quantity',
#  'Feed',
#  'Seed',
#  'Losses',
#  'Processing',
#  'Other uses (non-food)',
#  'Residuals',
#  'Food',
#  'Food supply quantity (kg/capita/yr)',
#  'Tourist consumption']

# %%
df["Element"].nunique()
# Out:
# 18

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df[['Element Code', 'Element']]
# Out:
#        Element Code                                 Element
# 0               511           Total Population - Both sexes
# 1              5301                Domestic supply quantity
# 2               664           Food supply (kcal/capita/day)
# 3               674  Protein supply quantity (g/capita/day)
# 4               684      Fat supply quantity (g/capita/day)
# ...             ...                                     ...
# 60938          5142                                    Food
# 60939           645     Food supply quantity (kg/capita/yr)
# 60940           664           Food supply (kcal/capita/day)
# 60941           674  Protein supply quantity (g/capita/day)
# 60942           684      Fat supply quantity (g/capita/day)
#
# [60943 rows x 2 columns]

# %% [markdown]
# ## kindly read up on these guys
# * .loc
# * .iloc

# %%
df.iloc[:,0:3]
# Out:
#        Area Code      Area  Item Code
# 0              4   Algeria       2501
# 1              4   Algeria       2501
# 2              4   Algeria       2901
# 3              4   Algeria       2901
# 4              4   Algeria       2901
# ...          ...       ...        ...
# 60938        181  Zimbabwe       2899
# 60939        181  Zimbabwe       2899
# 60940        181  Zimbabwe       2899
# 60941        181  Zimbabwe       2899
# 60942        181  Zimbabwe       2899
#
# [60943 rows x 3 columns]

# %%
df.loc[:,["Area Code","Item Code","Element"]]
# Out:
#        Area Code  Item Code                                 Element
# 0              4       2501           Total Population - Both sexes
# 1              4       2501                Domestic supply quantity
# 2              4       2901           Food supply (kcal/capita/day)
# 3              4       2901  Protein supply quantity (g/capita/day)
# 4              4       2901      Fat supply quantity (g/capita/day)
# ...          ...        ...                                     ...
# 60938        181       2899                                    Food
# 60939        181       2899     Food supply quantity (kg/capita/yr)
# 60940        181       2899           Food supply (kcal/capita/day)
# 60941        181       2899  Protein supply quantity (g/capita/day)
# 60942        181       2899      Fat supply quantity (g/capita/day)
#
# [60943 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# ?df

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
cols = ['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']

df.groupby("Element")[cols].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df['w'].value counts()
# Out:
#   Input In [41]
#     df['w'].value counts()
#                   ^
# SyntaxError: invalid syntax

# %%
len(df)
# Out:
# 60943

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df.fillna()
#
# File ~\anaconda3\envs\hamoye\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\hamoye\lib\site-packages\pandas\core\frame.py:5220, in DataFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    5209 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "value"])
#    5210 @doc(NDFrame.fillna, **_shared_doc_kwargs)
#    5211 def fillna(
#    (...)
#    5218     downcast=None,
# ...
